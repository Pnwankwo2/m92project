# %%
# Install the required libraries
import pandas as pd

# %%
#Identify URL and create dataframe
urls = ["https://stats.bis.org/api/v2/data/dataflow/BIS/WS_EER/1.0/D.N.B.US?format=csv"]
df = pd.concat([pd.read_csv(url) for url in urls])

df
# Out:
#       FREQ EER_TYPE EER_BASKET REF_AREA  UNIT_MEASURE  TIME_FORMAT COLLECTION  \
# 0        D        N          B       US           882          NaN          A
# 1        D        N          B       US           882          NaN          A
# 2        D        N          B       US           882          NaN          A
# 3        D        N          B       US           882          NaN          A
# 4        D        N          B       US           882          NaN          A
# ...    ...      ...        ...      ...           ...          ...        ...
# 10389    D        N          B       US           882          NaN          A
# 10390    D        N          B       US           882          NaN          A
# 10391    D        N          B       US           882          NaN          A
# 10392    D        N          B       US           882          NaN          A
# 10393    D        N          B       US           882          NaN          A
#
#                                              TITLE_TS TIME_PERIOD  OBS_VALUE  \
# 0      United States - Nominal - Broad (64 economies)  1996-04-11      77.43
# 1      United States - Nominal - Broad (64 economies)  1996-04-12      77.37
# 2      United States - Nominal - Broad (64 economies)  1996-04-13        NaN
# 3      United States - Nominal - Broad (64 economies)  1996-04-14        NaN
# 4      United States - Nominal - Broad (64 economies)  1996-04-15      77.49
# ...                                               ...         ...        ...
# 10389  United States - Nominal - Broad (64 economies)  2024-09-20     104.59
# 10390  United States - Nominal - Broad (64 economies)  2024-09-21        NaN
# 10391  United States - Nominal - Broad (64 economies)  2024-09-22        NaN
# 10392  United States - Nominal - Broad (64 economies)  2024-09-23     104.71
# 10393  United States - Nominal - Broad (64 economies)  2024-09-24     104.47
#
#       OBS_STATUS OBS_CONF  OBS_PRE_BREAK
# 0              A        F            NaN
# 1              A        F            NaN
# 2              H        F            NaN
# 3              H        F            NaN
# 4              A        F            NaN
# ...          ...      ...            ...
# 10389          A        F            NaN
# 10390          H        F            NaN
# 10391          H        F            NaN
# 10392          A        F            NaN
# 10393          A        F            NaN
#
# [10394 rows x 13 columns]

# %%
#Drop unwanted columns
df_filtered_columns = df.drop(['FREQ','EER_TYPE','EER_BASKET','REF_AREA','UNIT_MEASURE','TIME_FORMAT','COLLECTION','TITLE_TS','OBS_STATUS','OBS_CONF','OBS_PRE_BREAK'], axis=1)
# df_filtered_columns

#Drop unwanted rows
df_filtered_rows = df_filtered_columns.dropna()
# df_filtered_rows

#rename columns
df_renamed = df_filtered_rows.rename(columns={'TIME_PERIOD':'Date', 'OBS_VALUE':'Exchange_Rate'})
# df_renamed

#set index as the date column
df_renamed = df_renamed.set_index('Date')
# df_renamed.info()


# df_renamed.describe()

# df_renamed.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7424 entries, 1996-04-11 to 2024-09-24
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Exchange_Rate  7424 non-null   float64
# dtypes: float64(1)
# memory usage: 116.0+ KB
